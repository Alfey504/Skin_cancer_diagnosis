# %%
import pandas as pd
import os
import shutil

# %%
skin_df = pd.read_pickle("loaded_data/x_test_o.pkl")

# %%
skin_df.head()
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 6066  HAM_0000628  ISIC_0024567   nv  follow_up  35.0  female
# 7912  HAM_0004226  ISIC_0032760   nv      histo  25.0  female
# 7903  HAM_0002015  ISIC_0034035   nv      histo  30.0  female
# 7126  HAM_0001651  ISIC_0033251   nv      histo  45.0    male
# 692   HAM_0003206  ISIC_0025199  bkl      histo  60.0  female
#
#          localization                                     path  \
# 6066  lower extremity  HAM10000_images_part_1\ISIC_0024567.jpg
# 7912            trunk  HAM10000_images_part_2\ISIC_0032760.jpg
# 7903  lower extremity  HAM10000_images_part_2\ISIC_0034035.jpg
# 7126             back  HAM10000_images_part_2\ISIC_0033251.jpg
# 692   lower extremity  HAM10000_images_part_1\ISIC_0025199.jpg
#
#                            cell_type  \
# 6066                Melanocytic nevi
# 7912                Melanocytic nevi
# 7903                Melanocytic nevi
# 7126                Melanocytic nevi
# ...

# %%
skin_df = skin_df.drop('image',axis=1)

# %%
skin_df.head()
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 6066  HAM_0000628  ISIC_0024567   nv  follow_up  35.0  female
# 7912  HAM_0004226  ISIC_0032760   nv      histo  25.0  female
# 7903  HAM_0002015  ISIC_0034035   nv      histo  30.0  female
# 7126  HAM_0001651  ISIC_0033251   nv      histo  45.0    male
# 692   HAM_0003206  ISIC_0025199  bkl      histo  60.0  female
#
#          localization                                     path  \
# 6066  lower extremity  HAM10000_images_part_1\ISIC_0024567.jpg
# 7912            trunk  HAM10000_images_part_2\ISIC_0032760.jpg
# 7903  lower extremity  HAM10000_images_part_2\ISIC_0034035.jpg
# 7126             back  HAM10000_images_part_2\ISIC_0033251.jpg
# 692   lower extremity  HAM10000_images_part_1\ISIC_0025199.jpg
#
#                            cell_type
# 6066                Melanocytic nevi
# 7912                Melanocytic nevi
# 7903                Melanocytic nevi
# 7126                Melanocytic nevi
# ...

# %%
ld = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
target = "test_data"
for item in skin_df.values:
    
    if item[2] == 'nv':
        shutil.copy(item[7], os.path.join(target, ld['nv']))
    
    elif item[2] == 'mel':
        shutil.copy(item[7], os.path.join(target, ld['mel']))
    
    elif item[2] == 'bkl':
        shutil.copy(item[7], os.path.join(target, ld['bkl']))
    
    elif item[2] == 'bcc':
        shutil.copy(item[7], os.path.join(target, ld['bcc']))
        
    elif item[2] == 'akiec':
        shutil.copy(item[7], os.path.join(target, ld['akiec']))
        
    elif item[2] == 'vasc':
        shutil.copy(item[7], os.path.join(target, ld['vasc']))
        
    elif item[2] == 'df':
        shutil.copy(item[7], os.path.join(target, ld['df']))
